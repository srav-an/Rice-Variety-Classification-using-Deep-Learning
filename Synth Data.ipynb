# %%
pip install sdv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 102 kB 8.8 MB/s
# ...
#      |████████████████████████████████| 45 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 70.8 MB/s
# ...
#      |████████████████████████████████| 98 kB 10.1 MB/s
# ...
#      |████████████████████████████████| 46 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 54.9 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 930 kB 64.9 MB/s
# ...
#      |████████████████████████████████| 636 kB 66.5 MB/s
# ...
#      |████████████████████████████████| 281 kB 60.3 MB/s
# ...
#      |████████████████████████████████| 2.5 MB 52.3 MB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pyyaml
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("/content/drive/MyDrive/Mini prj/Code/Rice_MSC_Dataset.xlsx")
df.head()
# Out:
#    AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  7805    437.915    209.8215     48.0221        0.9735   99.6877    0.9775
# 1  7503    340.757    138.3361     69.8417        0.8632   97.7400    0.9660
# 2  5124    314.617    141.9803     46.5784        0.9447   80.7718    0.9721
# 3  7990    437.085    201.4386     51.2245        0.9671  100.8622    0.9659
# 4  7433    342.893    140.3350     68.3927        0.8732   97.2830    0.9831
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  ALLdaub4b  \
# 0         7985  0.3547        4.3693  ...   113.9924    65.0610    59.5989
# 1         7767  0.6637        1.9807  ...   105.7055    64.3685    62.2084
# 2         5271  0.4760        3.0482  ...   109.7155    62.6423    58.7439
# 3         8272  0.6274        3.9325  ...   116.5405    64.9069    60.2562
# 4         7561  0.6006        2.0519  ...   107.7502    64.7071    61.3549
#
# ...

# %%
from sdv.tabular import GaussianCopula
model = GaussianCopula()
model.fit(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/copulas/univariate/truncated_gaussian.py:45: RuntimeWarning: divide by zero encountered in double_scalars
#   a = (self.min - loc) / scale
# /usr/local/lib/python3.7/dist-packages/copulas/univariate/truncated_gaussian.py:46: RuntimeWarning: divide by zero encountered in double_scalars
#   b = (self.max - loc) / scale

# %%
sample = model.sample(90)
sample.head()
# Out:
#    Unnamed: 0   AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# 0          19   9716    547.535    249.4108     41.1819        0.9815
# 1          45   7931    383.809    175.6010     64.2729        0.9071
# 2          32  12401    351.385    145.8235     85.8819        0.8034
# 3          79   9174    344.957    142.6098     75.6790        0.8710
# 4          50   5098    290.683    117.5739     72.9539        0.7852
#
#     EQDIASQ  SOLIDITY  CONVEX_AREA  EXTENT  ...  ALLdaub4L  ALLdaub4a  \
# 0  105.3056    0.9734         9971  0.4033  ...   114.5690    62.2530
# 1   96.6190    0.9734         8159  0.6179  ...   113.1824    64.3837
# 2  122.0572    0.9748        12701  0.8218  ...   112.2439    64.9233
# 3  102.7428    0.9739         9411  0.7118  ...   110.4438    64.1820
# 4   80.4152    0.9750         5229  0.7946  ...   108.2576    64.8017
#
#    ALLdaub4b  ALLdaub4Y  ALLdaub4Cb  ALLdaub4Cr  ALLdaub4XX  ALLdaub4YY  \
# ...

# %%
df['CLASS'].unique()
# Out:
# array(['Jasmine', 'Basmati', 'Arborio', 'Ipsala', 'Karacadag'],
#       dtype=object)

# %%
df=pd.read_csv("/content/drive/MyDrive/Mini prj/Code/synthetic_data.csv")
df
# Out:
#       AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0     5124    314.617    141.9803     46.5784        0.9447   80.7718
# 1     5450    320.362    139.9963     50.6910        0.9321   83.3016
# 2     9656    451.287    206.7047     60.2333        0.9566  110.8801
# 3     5251    327.214    151.2670     45.0754        0.9546   81.7666
# 4     5392    326.326    142.1714     48.9332        0.9389   82.8572
# ...    ...        ...         ...         ...           ...       ...
# 1245  5547    275.598    104.8386     68.3231        0.7585   84.0396
# 1246  6705    306.981    114.8573     75.6423        0.7525   92.3963
# 1247  5979    284.206    105.5677     72.8221        0.7240   87.2508
# 1248  5874    283.859    108.7729     69.2025        0.7715   86.4813
# 1249  6460    298.199    108.5409     76.6602        0.7079   90.6925
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  \
# ...

# %%
df_filtered1 = df[df['CLASS'] == 'Jasmine']
df_filtered2 = df[df['CLASS'] == 'Basmati']
df_filtered3 = df[df['CLASS'] == 'Arborio']
df_filtered4 = df[df['CLASS'] == 'Ipsala']
df_filtered5 = df[df['CLASS'] == 'Karacadag']

# %%
df_filtered1 = df_filtered1[:150]
df_filtered2 = df_filtered2[:150]
df_filtered3 = df_filtered3[:150]
df_filtered4 = df_filtered4[:150]
df_filtered5 = df_filtered5[:150]

# %%
df_filtered2
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 250  7805    437.915    209.8215     48.0221        0.9735   99.6877
# 251  7990    437.085    201.4386     51.2245        0.9671  100.8622
# 252  7621    450.325    219.0981     45.2301        0.9785   98.5056
# 253  7090    401.778    190.9745     47.8482        0.9681   95.0119
# 254  7116    411.103    197.0442     46.7342        0.9715   95.1860
# ..    ...        ...         ...         ...           ...       ...
# 395  7400    418.873    199.5758     48.1629        0.9704   97.0668
# 396  5671    372.306    176.7418     41.1014        0.9726   84.9738
# 397  6069    395.649    188.5542     41.7402        0.9752   87.9050
# 398  7203    436.931    212.3937     44.4770        0.9778   95.7661
# 399  7944    429.896    202.9118     51.4028        0.9674  100.5714
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  \
# ...

# %%
df_synth = df_filtered1.append(df_filtered2)

# %%
df_synth = df_synth.append(df_filtered3)
df_synth = df_synth.append(df_filtered4)
df_synth = df_synth.append(df_filtered5)

# %%
df_synth.tail()
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 743  7400    418.873    199.5758     48.1629        0.9704   97.0668
# 752  5671    372.306    176.7418     41.1014        0.9726   84.9738
# 760  6069    395.649    188.5542     41.7402        0.9752   87.9050
# 769  7203    436.931    212.3937     44.4770        0.9778   95.7661
# 773  7944    429.896    202.9118     51.4028        0.9674  100.5714
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  \
# 743    0.9774         7571  0.7668        4.1438  ...   108.1999    65.7787
# 752    0.9746         5819  0.5193        4.3001  ...   111.6388    65.6438
# 760    0.9770         6212  0.3613        4.5173  ...   111.7372    64.8697
# 769    0.9648         7466  0.3859        4.7754  ...   107.8197    65.6598
# 773    0.9633         8247  0.4028        3.9475  ...   114.2141    65.2243
#
#      ALLdaub4b  ALLdaub4Y  ALLdaub4Cb  ALLdaub4Cr  ALLdaub4XX  ALLdaub4YY  \
# ...

# %%
df_synth.to_csv("/content/drive/MyDrive/Mini prj/Code/synthetic_data.csv")
